# %% [markdown]
# # Pandas

# %% [markdown]
# ## pandas ===> it is an open-source library that is used for handle data manupulations.

# %%
# Data structure : 
# (1) Series  (2) DataFrame

# %% [markdown]
# ## Series

# %%
import pandas as pd

# %%
a = pd.Series([1,23,67,90])
a
# Out:
# 0     1
# 1    23
# 2    67
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# dict

# %% [markdown]
# ## (2) DataFrame

# %%
a = {
    "Emp_ID" : [1,2,3,4,5,6,7,8],
    "Name" : ['Sam', 'Mohit', 'Gorav', 'Aniket', 'Raj', 'Rahul', 'Deepak', 'Kunal'],
    "Department" : ['IT', 'HR', 'HR', 'IT', 'Operations', 'IT', 'Operations', 'HR'],
    "Working_Hours" : [8,9,9,9,9,9,6,7]
}
a
# Out:
# {'Emp_ID': [1, 2, 3, 4, 5, 6, 7, 8],
#  'Name': ['Sam',
#   'Mohit',
#   'Gorav',
#   'Aniket',
#   'Raj',
#   'Rahul',
#   'Deepak',
#   'Kunal'],
#  'Department': ['IT',
#   'HR',
#   'HR',
#   'IT',
#   'Operations',
#   'IT',
#   'Operations',
#   'HR'],
#  'Working_Hours': [8, 9, 9, 9, 9, 9, 6, 7]}

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 0       1     Sam          IT              8
# 1       2   Mohit          HR              9
# 2       3   Gorav          HR              9
# 3       4  Aniket          IT              9
# 4       5     Raj  Operations              9
# 5       6   Rahul          IT              9
# 6       7  Deepak  Operations              6
# 7       8   Kunal          HR              7

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Department', 'Working_Hours'], dtype='object')

# %%
df.head() #top 5 data
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 0       1     Sam          IT              8
# 1       2   Mohit          HR              9
# 2       3   Gorav          HR              9
# 3       4  Aniket          IT              9
# 4       5     Raj  Operations              9

# %%
df.head(2)
# Out:
#    Emp_ID   Name Department  Working_Hours
# 0       1    Sam         IT              8
# 1       2  Mohit         HR              9

# %%
df.tail()
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 3       4  Aniket          IT              9
# 4       5     Raj  Operations              9
# 5       6   Rahul          IT              9
# 6       7  Deepak  Operations              6
# 7       8   Kunal          HR              7

# %%
df.tail(2)
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 6       7  Deepak  Operations              6
# 7       8   Kunal          HR              7

# %%
df.sample(4) # it returns random-indexed rows.
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 5       6   Rahul          IT              9
# 6       7  Deepak  Operations              6
# 0       1     Sam          IT              8
# 2       3   Gorav          HR              9

# %%
df.describe() # i returns statically view of data.
# Out:
#         Emp_ID  Working_Hours
# count  8.00000       8.000000
# mean   4.50000       8.250000
# std    2.44949       1.164965
# min    1.00000       6.000000
# 25%    2.75000       7.750000
# 50%    4.50000       9.000000
# 75%    6.25000       9.000000
# max    8.00000       9.000000

# %%
df.info() #complete overview of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Emp_ID         8 non-null      int64
#  1   Name           8 non-null      object
#  2   Department     8 non-null      object
#  3   Working_Hours  8 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
if you want to export your data in csv format

# %%
df.to_csv("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\csv\\Emp_Info.csv")

# %%
df.to_csv("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\csv\\New_Emp_Info.csv", index = False)

# %%
df.to_excel("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\csv\\Old_Emp_Info.xlsx")

# %% [markdown]
# ## How to open csv file in jupyter notebook

# %%
df = pd.read_csv("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\csv\\New_Emp_Info.csv")

# %%
df.head()
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 0       1     Sam          IT              8
# 1       2   Mohit          HR              9
# 2       3   Gorav          HR              9
# 3       4  Aniket          IT              9
# 4       5     Raj  Operations              9

# %%
df['Department']
# Out:
# 0            IT
# 1            HR
# 2            HR
# 3            IT
# 4    Operations
# 5            IT
# 6    Operations
# 7            HR
# Name: Department, dtype: object

# %%
df['Department'].value_counts()
# Out:
# IT            3
# HR            3
# Operations    2
# Name: Department, dtype: int64

# %%
a = {
    "Emp_ID" : [1,2,3,4,5,6,7,8],
    "Name" : ['Sam', 'Mohit', 'Gorav', 'Aniket', 'Raj', 'Rahul', 'Deepak', 'Kunal'],
    "Department" : ['IT', 'HR', 'HR', 'IT', 'Operations', 'IT', 'Operations', 'HR'],
    "Working_Hours" : [8,9,9,9,9,9,6,7]
}
a
# Out:
# {'Emp_ID': [1, 2, 3, 4, 5, 6, 7, 8],
#  'Name': ['Sam',
#   'Mohit',
#   'Gorav',
#   'Aniket',
#   'Raj',
#   'Rahul',
#   'Deepak',
#   'Kunal'],
#  'Department': ['IT',
#   'HR',
#   'HR',
#   'IT',
#   'Operations',
#   'IT',
#   'Operations',
#   'HR'],
#  'Working_Hours': [8, 9, 9, 9, 9, 9, 6, 7]}

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 0       1     Sam          IT              8
# 1       2   Mohit          HR              9
# 2       3   Gorav          HR              9
# 3       4  Aniket          IT              9
# 4       5     Raj  Operations              9
# 5       6   Rahul          IT              9
# 6       7  Deepak  Operations              6
# 7       8   Kunal          HR              7

# %%
df['Name'][0] = 'Kriti'
# Out:
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\1991129534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][0] = 'Kriti'

# %%
df
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 0       1   Kriti          IT              8
# 1       2   Mohit          HR              9
# 2       3   Gorav          HR              9
# 3       4  Aniket          IT              9
# 4       5     Raj  Operations              9
# 5       6   Rahul          IT              9
# 6       7  Deepak  Operations              6
# 7       8   Kunal          HR              7

# %%
#Raj ==> working_hours =7
df['Name'][]
# Out:
#   File "C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\1884593884.py", line 2
#     df['Name'][]
#                ^
# SyntaxError: invalid syntax

# %%
# loc and iloc

# df.loc['row_range','column_name']
# df.loc['row_range','column_range']

# %%
df.loc[2:5, ["Name", "Department"]]
# Out:
#      Name  Department
# 2   Gorav          HR
# 3  Aniket          IT
# 4     Raj  Operations
# 5   Rahul          IT

# %%
df.iloc[2:5, [1,2]]
# Out:
#      Name  Department
# 2   Gorav          HR
# 3  Aniket          IT
# 4     Raj  Operations

# %%
df['Name'][2] = None
df['Department'][3] = None
df['Department'][4] = None
# Out:
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\2836322762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][2] = None
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\2836322762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Department'][3] = None
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\2836322762.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Department'][4] = None

# %%
df
# Out:
#    Emp_ID    Name  Department  Working_Hours
# 0       1   Kriti          IT              8
# 1       2   Mohit          HR              9
# 2       3    None          HR              9
# 3       4  Aniket        None              9
# 4       5     Raj        None              9
# 5       6   Rahul          IT              9
# 6       7  Deepak  Operations              6
# 7       8   Kunal          HR              7

# %%
df.isnull() # it will returns true if you have missing values otherwise return False
# Out:
#    Emp_ID   Name  Department  Working_Hours
# 0   False  False       False          False
# 1   False  False       False          False
# 2   False   True       False          False
# 3   False  False        True          False
# 4   False  False        True          False
# 5   False  False       False          False
# 6   False  False       False          False
# 7   False  False       False          False

# %%
df.isnull().sum() #we can check total missing values
# Out:
# Emp_ID           0
# Name             1
# Department       2
# Working_Hours    0
# dtype: int64

# %%
df.notnull() # it will returns false if you have missing values otherwise return true
# Out:
#    Emp_ID   Name  Department  Working_Hours
# 0    True   True        True           True
# 1    True   True        True           True
# 2    True  False        True           True
# 3    True   True       False           True
# 4    True   True       False           True
# 5    True   True        True           True
# 6    True   True        True           True
# 7    True   True        True           True

# %%
df.notnull().sum() #we can check total present values
# Out:
# Emp_ID           8
# Name             7
# Department       6
# Working_Hours    8
# dtype: int64

# %% [markdown]
# # Assignment

# %% [markdown]
# ## file name covid_toy.csv

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\Assignment_2\\covid_toy.csv")
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['gender'].value_counts()
# Out:
# Female    59
# Male      41
# Name: gender, dtype: int64

# %%
df['age'][0] = '100'
# Out:
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\3385653375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][0] = '100'

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0   100    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.loc[2:5, ["age", "gender"]]
# Out:
#   age  gender
# 2  42    Male
# 3  31  Female
# 4  65  Female
# 5  84  Female

# %%
df.iloc[2:5, [1,2]]
# Out:
#    gender  fever
# 2    Male  101.0
# 3  Female   98.0
# 4  Female  101.0

# %%
df['age'][0] = None
df['age'][1] = None
df['age'][2] = None

# %%
df
# Out:
#      age  gender  fever   cough       city has_covid
# 0   None    Male  103.0    Mild    Kolkata        No
# 1   None    Male  100.0    Mild      Delhi       Yes
# 2   None    Male  101.0    Mild      Delhi        No
# 3     31  Female   98.0    Mild    Kolkata        No
# 4     65  Female  101.0    Mild     Mumbai        No
# ..   ...     ...    ...     ...        ...       ...
# 95    12  Female  104.0    Mild  Bangalore        No
# 96    51  Female  101.0  Strong    Kolkata       Yes
# 97    20  Female  101.0    Mild  Bangalore        No
# 98     5  Female   98.0  Strong     Mumbai        No
# 99    10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.isnull() # it will returns true if you have missing values otherwise return False
# Out:
#       age  gender  fever  cough   city  has_covid
# 0    True   False  False  False  False      False
# 1    True   False  False  False  False      False
# 2    True   False  False  False  False      False
# 3   False   False  False  False  False      False
# 4   False   False  False  False  False      False
# ..    ...     ...    ...    ...    ...        ...
# 95  False   False  False  False  False      False
# 96  False   False  False  False  False      False
# 97  False   False  False  False  False      False
# 98  False   False  False  False  False      False
# 99  False   False  False  False  False      False
#
# [100 rows x 6 columns]

# %%
df.isnull().sum() #we can check total missing values
# Out:
# age           3
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.notnull() # it will returns false if you have missing values otherwise return true
# Out:
#       age  gender  fever  cough  city  has_covid
# 0   False    True   True   True  True       True
# 1   False    True   True   True  True       True
# 2   False    True   True   True  True       True
# 3    True    True   True   True  True       True
# 4    True    True   True   True  True       True
# ..    ...     ...    ...    ...   ...        ...
# 95   True    True   True   True  True       True
# 96   True    True   True   True  True       True
# 97   True    True   True   True  True       True
# 98   True    True   True   True  True       True
# 99   True    True   True   True  True       True
#
# [100 rows x 6 columns]

# %%
df.notnull().sum() # it will returns false if you have missing values otherwise return true
# Out:
# age           97
# gender       100
# fever         90
# cough        100
# city         100
# has_covid    100
# dtype: int64

# %% [markdown]
# ## file name insurance.csv

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\Assignment_2\\insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['sex'][0] = 'male'
df
# Out:
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\910709306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex'][0] = 'male'
#       age     sex     bmi  children smoker     region      charges
# 0      19    male  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.loc[2:5, ["age", "sex"]]
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19    male  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.iloc[2:5, [1,2]]
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19    male  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['age'][0] = None
df['age'][1] = None
df['age'][2] = None
df
# Out:
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\3711609032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][0] = None
#        age     sex     bmi  children smoker     region      charges
# 0      NaN    male  27.900         0    yes  southwest  16884.92400
# 1      NaN    male  33.770         1     no  southeast   1725.55230
# 2      NaN    male  33.000         3     no  southeast   4449.46200
# 3     33.0    male  22.705         0     no  northwest  21984.47061
# 4     32.0    male  28.880         0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 1333  50.0    male  30.970         3     no  northwest  10600.54830
# 1334  18.0  female  31.920         0     no  northeast   2205.98080
# 1335  18.0  female  36.850         0     no  southeast   1629.83350
# 1336  21.0  female  25.800         0     no  southwest   2007.94500
# 1337  61.0  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isnull() # it will returns true if you have missing values otherwise return False
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0      True  False  False     False   False   False    False
# 1      True  False  False     False   False   False    False
# 2      True  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
df.isnull().sum() #we can check total missing values
# Out:
# age         3
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ## file name placement

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\deepak\\Summer Intership and Training\\Machine_Learning\\Assignment_2\\placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df['cgpa'].value_counts()
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'][0] = '9.00'
df
# Out:
# C:\Users\deepak\AppData\Local\Temp\ipykernel_5664\3814182584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cgpa'][0] = '9.00'
#     cgpa  resume_score  placed
# 0   9.00          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
print(df.loc[2:5, ["cgpa", "placed"]])
print(df.iloc[2:5, [1,2]])
# Out:
#    cgpa  placed
# 2  8.27       1
# 3  6.88       1
# 4  7.52       1
# 5  8.77       1
#    resume_score  placed
# 2          8.86       1
# 3          7.27       1
# 4          7.30       1

# %%
df['cgpa'][0] = None
df['cgpa'][1] = None
df['cgpa'][2] = None
df
# Out:
#     cgpa  resume_score  placed
# 0   None          6.52       1
# 1   None          5.17       0
# 2   None          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.isnull() # it will returns true if you have missing values otherwise return False
# Out:
#      cgpa  resume_score  placed
# 0    True         False   False
# 1    True         False   False
# 2    True         False   False
# 3   False         False   False
# 4   False         False   False
# ..    ...           ...     ...
# 95  False         False   False
# 96  False         False   False
# 97  False         False   False
# 98  False         False   False
# 99  False         False   False
#
# [100 rows x 3 columns]

# %%
df.isnull().sum() #we can check total missing values
# Out:
# cgpa            3
# resume_score    0
# placed          0
# dtype: int64

# %%
df.notnull().sum() # it will returns false if you have missing values otherwise return true
# Out:
# cgpa             97
# resume_score    100
# placed          100
# dtype: int64
